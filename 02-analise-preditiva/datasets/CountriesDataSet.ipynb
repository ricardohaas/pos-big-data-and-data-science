# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://courses.edx.org/c4x/MITx/15.071x_2/asset/WHO.csv')

# %%
df.head()
# Out:
#        Country                 Region  Population  Under15  Over60  \
# 0  Afghanistan  Eastern Mediterranean       29825    47.42    3.82
# 1      Albania                 Europe        3162    21.33   14.93
# 2      Algeria                 Africa       38482    27.42    7.17
# 3      Andorra                 Europe          78    15.20   22.86
# 4       Angola                 Africa       20821    47.58    3.84
#
#    FertilityRate  LifeExpectancy  ChildMortality  CellularSubscribers  \
# 0           5.40              60            98.5                54.26
# 1           1.75              74            16.7                96.39
# 2           2.83              73            20.0                98.99
# 3            NaN              82             3.2                75.49
# 4           6.10              51           163.5                48.38
#
#    LiteracyRate     GNI  PrimarySchoolEnrollmentMale  \
# 0           NaN  1140.0                          NaN
# ...

# %%
df.describe()
# Out:
#          Population     Under15      Over60  FertilityRate  LifeExpectancy  \
# count  1.940000e+02  194.000000  194.000000     183.000000      194.000000
# mean   3.635997e+04   28.732423   11.163660       2.940656       70.010309
# std    1.379031e+05   10.534573    7.149331       1.480984        9.259075
# min    1.000000e+00   13.120000    0.810000       1.260000       47.000000
# 25%    1.695750e+03   18.717500    5.200000       1.835000       64.000000
# 50%    7.790000e+03   28.650000    8.530000       2.400000       72.500000
# 75%    2.453525e+04   37.752500   16.687500       3.905000       76.000000
# max    1.390000e+06   49.990000   31.920000       7.580000       83.000000
#
#        ChildMortality  CellularSubscribers  LiteracyRate           GNI  \
# count      194.000000           184.000000    103.000000    162.000000
# mean        36.148969            93.641522     83.710680  13320.925926
# std         37.992935            41.400447     17.530645  15192.988650
# ...

# %%
# Mean of over60 population
df.Over60.mean()
# Out:
# 11.163659793814434

# %%
# Country has the smallest percentage of the population over 60?
index_small60 = df.Over60.idxmin()
df.iloc[index_small60]['Country']
# Out:
# 'United Arab Emirates'

# %%
# Country has the smallest percentage of the population over 60?
index_highLR = df.LiteracyRate.idxmax()
df.iloc[index_highLR]['Country']
# Out:
# 'Cuba'

# %%
df.head()
# Out:
#        Country                 Region  Population  Under15  Over60  \
# 0  Afghanistan  Eastern Mediterranean       29825    47.42    3.82
# 1      Albania                 Europe        3162    21.33   14.93
# 2      Algeria                 Africa       38482    27.42    7.17
# 3      Andorra                 Europe          78    15.20   22.86
# 4       Angola                 Africa       20821    47.58    3.84
#
#    FertilityRate  LifeExpectancy  ChildMortality  CellularSubscribers  \
# 0           5.40              60            98.5                54.26
# 1           1.75              74            16.7                96.39
# 2           2.83              73            20.0                98.99
# 3            NaN              82             3.2                75.49
# 4           6.10              51           163.5                48.38
#
#    LiteracyRate     GNI  PrimarySchoolEnrollmentMale  \
# 0           NaN  1140.0                          NaN
# ...

# %%
#Region with min mean Child Mortality?
groupeddd = df.groupby(['Region', 'Country']).sum()
grouped
# Out:
#                                                   Population  Under15  Over60  \
# Region          Country
# Africa          Algeria                                38482    27.42    7.17
#                 Angola                                 20821    47.58    3.84
#                 Benin                                  10051    42.95    4.54
#                 Botswana                                2004    33.75    5.63
#                 Burkina Faso                           16460    45.66    3.88
#                 Burundi                                 9850    44.20    3.87
#                 Cameroon                               21700    43.08    4.89
#                 Cape Verde                               494    30.17    7.05
#                 Central African Republic                4525    40.07    5.74
#                 Chad                                   12448    48.52    3.80
#                 Comoros                                  718    42.17    4.50
# ...

# %%
means = grouped.mean(level=0, axis=0)
means
# Out:
#                           Population    Under15     Over60  FertilityRate  \
# Region
# Africa                  19406.434783  40.937826   5.220652       4.724565
# Americas                27364.828571  27.437429  10.943714       2.210571
# Eastern Mediterranean   27827.863636  30.954091   5.620000       3.245000
# Europe                  17062.547170  18.039434  19.774906       1.661509
# South-East Asia        167010.090909  29.056364   8.769091       2.560909
# Western Pacific         68508.555556  28.664444  10.162963       2.067407
#
#                        LifeExpectancy  ChildMortality  CellularSubscribers  \
# Region
# Africa                      57.956522       84.036957            63.018043
# Americas                    74.342857       19.322857           103.962286
# Eastern Mediterranean       69.590909       40.250000            94.648182
# Europe                      76.735849       10.050943           112.686981
# ...

# %%
index_CM = means.ChildMortality.idxmin()
index_CM
# Out:
# 'Europe'
